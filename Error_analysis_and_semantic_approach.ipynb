# %% [markdown]
# # **Second improvement and error analysis**

# %% [markdown]
# Here is implemented the second improvement, an attempt to introduce some semantic inside the model, trying to replace words in the queries which were not working well with synonyms which could perform better.
# In the second part of the notebook is shown the error analysis that led to this approach

# %%
# !pip install python-terrier
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.8.0.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 3.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.3.5)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from python-terrier) (4.63.0)
# Collecting pyjnius~=1.3.0
#   Downloading pyjnius-1.3.0-cp37-cp37m-manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 36.8 MB/s
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 5.9 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.0)
# Collecting deprecation
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.23.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.1.0)
# Collecting nptyping
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from python-terrier) (8.12.0)
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.0-py3-none-any.whl (255 kB)
#      |████████████████████████████████| 255 kB 69.5 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.10.2)
# Collecting ir_measures>=0.2.0
#   Downloading ir_measures-0.2.3.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 296 kB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.3.4)
# Collecting lxml>=4.5.2
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 36.6 MB/s
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting lz4>=3.1.1
#   Downloading lz4-4.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 47.1 MB/s
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting ijson>=3.1.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 54.5 MB/s
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 55.8 MB/s
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.6.3)
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp37-cp37m-manylinux2010_x86_64.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.6 MB/s
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 41.9 MB/s
# Collecting pytrec-eval-terrier==0.5.1
#   Downloading pytrec_eval_terrier-0.5.1-cp37-cp37m-manylinux2010_x86_64.whl (291 kB)
#      |████████████████████████████████| 291 kB 59.0 MB/s
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.10.tar.gz (31 kB)
# Collecting pyndeval>=0.0.2
#   Downloading pyndeval-0.0.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (59 kB)
#      |████████████████████████████████| 59 kB 7.1 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (0.29.28)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (1.24.3)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation->python-terrier) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->python-terrier) (2.0.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.1 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation->python-terrier) (3.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->python-terrier) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->python-terrier) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->python-terrier) (0.5.2)
# Building wheels for collected packages: python-terrier, ir-measures, cwl-eval, cbor, warc3-wet-clueweb09, chest, wget
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.8.0-py3-none-any.whl size=103883 sha256=ee0463a852a33a5993deb232e5d77fa55c15055dbb07b609de77975ddfd351f2
#   Stored in directory: /root/.cache/pip/wheels/a8/ec/0c/fd9fcb409ad158d1f62534f9b1924b406f420f1a4170fb4132
#   Building wheel for ir-measures (setup.py) ... done
#   Created wheel for ir-measures: filename=ir_measures-0.2.3-py3-none-any.whl size=53217 sha256=cb4b5c398979d0a86d58d7338e095b6a6770f443b6c47ee69c6483d41febb2eb
#   Stored in directory: /root/.cache/pip/wheels/b2/06/1b/b8dc2d9a9802a9c30dd3a28d4199061297df0034d8ab9b808a
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.10-py3-none-any.whl size=37797 sha256=45208d2664d7508d0395554cf03f6a570dff9cbf72eb71ff3b08081cc049017f
#   Stored in directory: /root/.cache/pip/wheels/ff/e9/ff/d2b6d72d9feb0d0b1b11aacfaf5cd866717034615c2d194093
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp37-cp37m-linux_x86_64.whl size=51315 sha256=e914c67ca75b0da7c769ac4099545707134704ce0aaae9afa09b471871c0105f
#   Stored in directory: /root/.cache/pip/wheels/19/77/49/c9c2c8dc5848502e606e8579d0bbda18b850fb056a6c62239d
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18922 sha256=a5130e06744c9b70f8cf6095f2e76a7334fb6edc26a78cc505317a13d34670ee
#   Stored in directory: /root/.cache/pip/wheels/42/d4/3c/7c2b0c3d400ad744e4db69f2fde166655da2ed2198bfc02db6
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7634 sha256=87db14cf885751e8e76cc6c451e1b90549fc87eb88ede689a26197043121236b
#   Stored in directory: /root/.cache/pip/wheels/fc/f5/b9/c436e11300809e6b40d46a5d2592fb0bff89e0712f2e878dc7
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=48a6df24e412fa9077e12d6f6ef491fc9c08a33dac2e03850b08003cabcd0e36
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built python-terrier ir-measures cwl-eval cbor warc3-wet-clueweb09 chest wget
# Installing collected packages: cbor, zlib-state, warc3-wet-clueweb09, warc3-wet, typish, trec-car-tools, pyyaml, pytrec-eval-terrier, pyndeval, pyautocorpus, multiset, lz4, lxml, ijson, cwl-eval, wget, pyjnius, nptyping, matchpy, ir-measures, ir-datasets, deprecation, chest, python-terrier
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.10 deprecation-2.1.0 ijson-3.1.4 ir-datasets-0.5.0 ir-measures-0.2.3 lxml-4.8.0 lz4-4.0.0 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.8 pyjnius-1.3.0 pyndeval-0.0.2 python-terrier-0.8.0 pytrec-eval-terrier-0.5.1 pyyaml-6.0 trec-car-tools-2.6 typish-1.9.3 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5

# %%
import pyterrier as pt
pt.init(mem=20000, boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# terrier-assemblies 5.6 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.6 jar not found, downloading to /root/.pyterrier...
# Done
# terrier-prf -SNAPSHOT jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.8.0 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %%
dataset = pt.datasets.get_dataset("trec-deep-learning-passages")

# %%
def msmarco_generate():
    dataset = pt.get_dataset("trec-deep-learning-passages")
    with pt.io.autoopen(dataset.get_corpus()[0], 'rt') as corpusfile:
        for l in corpusfile:
            docno, passage = l.split("\t")
            yield {'docno' : docno, 'text' : passage}

iter_indexer = pt.IterDictIndexer("./passage_index")
indexref = iter_indexer.index(msmarco_generate(), meta={'docno' : 20, 'text': 4096})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: specifying meta and meta_lengths in IterDictIndexer.index() is deprecated, use constructor instead
#   if __name__ == '__main__':
# Downloading msmarco_passage corpus to /root/.pyterrier/corpora/msmarco_passage/corpus
# Downloading msmarco_passage tars to /root/.pyterrier/corpora/msmarco_passage/collection.tar.gz
# collection.tar.gz:   0%|          | 0.00/987M [00:00<?, ?iB/s]
# 08:33:22.692 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (500080) - further warnings are suppressed
# 08:58:10.621 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Indexed 5 empty documents

# %%
index = pt.IndexFactory.of(indexref)

# %%
# Aggregate of everything
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 8841823
# Number of terms: 1170682
# Number of postings: 215238456
# Number of fields: 1
# Number of tokens: 288759529
# Field names: [text]
# Positions:   false

# %%
bm25 = pt.BatchRetrieve(index, wmodel="BM25")

# %%
from pandas._libs.tslibs.timedeltas import ints_to_pytimedelta
import requests
from bs4 import BeautifulSoup

#Retrieve the synonyms for a single word
def get_synonyms_for(word):
  response = requests.get("https://www.thesaurus.com/browse/{}".format(word))
  soup = BeautifulSoup(response.content, 'html.parser')

  synonyms = soup.find("ul",{"class","css-1i3oiir e1ccqdb60"})

  in_other_words = []

  #if there are no synonyms, return an empty list
  if synonyms is None:
    print('No synonyms have been found for ' + word)
    return in_other_words

  #otherwise, create the list of synonyms
  for synonym in synonyms:
    if "inline-block" in synonym.text:
      continue
    else:
      in_other_words.append(synonym.text.strip())

  #print(synonyms)
  print('\n synonyms for: {}'.format(word) + ': ')
  print(in_other_words)
  return in_other_words

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import operator

#Create a new query, swapping words which are less present in the passages with the synonym which is more present
def replace_with_high_idf_synonym(q):
  ps = PorterStemmer()
  words = q["query"].split(" ")
  new_query = ""

  stopwords = ["does", "do", "in", "are", "is"]

  for w in words:
    if w in stopwords:
      new_query += ' ' + w
      continue
    try:
      i = index.getLexicon()[w].getDocumentFrequency()
      print('document freq of ' + w +": " + str(i))
    except:
      i = 0
      print(w + ' is not present in the index')

    synonyms = get_synonyms_for(w)

    if len(synonyms) == 0:
      new_query += ' ' + w
      continue

    d = {}
    for s in synonyms:
      try:
        i_s = index.getLexicon()[ps.stem(s)].getDocumentFrequency()
      except:
        continue
      if i_s > i:
          d[s] = i_s

    if len(d) > 0:
      max_idf_synonym = max(d.items(), key=operator.itemgetter(1))[0]
      print('The synonym chosen is ' + max_idf_synonym)
      new_query += ' ' + max_idf_synonym
    else:
      new_query += ' ' + w
      
  print('The original query was: ' + q["query"])
  print('The new query is: ' + new_query)
  return new_query

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import operator

#Create a new query, swapping only the words which are NOT present in the passages with the synonym which is more present
def replace_with_high_idf_synonym_only_if_not_in_passages(q):
  ps = PorterStemmer()
  words = q["query"].split(" ")
  new_query = ""

  stopwords = ["does", "do", "in", "are", "is"]

  for w in words:
    if w in stopwords:
      new_query += ' ' + w
      continue
    #If the word is already present in the document, which means that the getDocumentFrequency() gives no error, it is not going to be replaced
    try:
      i = index.getLexicon()[w].getDocumentFrequency()
      print('document freq of ' + w +": " + str(i) + '. Since this word is present in the documents, it is not going to be replaced.')
      new_query += ' ' + w
      continue
    except:
      i = 0
      print(w + ' is not present in the index, so it is going to be replaced.')

    synonyms = get_synonyms_for(w)

    if len(synonyms) == 0:
      new_query += ' ' + w
      continue

    d = {}
    for s in synonyms:
      try:
        i_s = index.getLexicon()[ps.stem(s)].getDocumentFrequency()
      except:
        continue
      if i_s > i:
          d[s] = i_s

    if len(d) > 0:
      max_idf_synonym = max(d.items(), key=operator.itemgetter(1))[0]
      print('The synonym chosen is ' + max_idf_synonym)
      new_query += ' ' + max_idf_synonym
    else:
      new_query += ' ' + w
      
  print('The original query was: ' + q["query"])
  print('The new query is: ' + new_query)
  return new_query

# %%
#Since the previous methods did not work well, we manually implemented two dictionaries in order to replace words
#based on that we found on the error analysis
dictionary_abbreviations = {"ww1": "world war 1", "us" : "united states" , "lps" : "lanterman petris short", "rn" : "registered nurse", "bsn" : "bachelor of science in nursing" }
dictionary_synonyms = {"pelvic" : ["stomach"], "visceral" : ["internal"], "wifi" : ["Wi-Fi"], "thai" : ["thailand"], "margin" : ["boundary"] , "cerebral" : ["brainy"], "temperature" : ["condition"]}

# %%
#Replace a list of words which are considered abbreviations with the full sentence 
def replace_abbreviations(q):
  words = q["query"].split(" ")

  print('The original query was: ' + q["query"])

  for w in words:
    if w in dictionary_abbreviations.keys():
      q["query"] = q["query"].replace(w, dictionary_abbreviations[w])

  print('The new query is: ' + q["query"])
  return q["query"]

# %%
def get_manually_synonyms(word):
  if word in dictionary_synonyms:
    return dictionary_synonyms.get(word)

# %%
#Replace a list of words with their synonyms which have been chosen directly by us
def replace_with_high_idf_synonym_manual(q):
  ps = PorterStemmer()
  words = q["query"].split(" ")
  new_query = ""
  
  stopwords = ["does", "do", "in", "are", "is"]

  for w in words:
    if w in stopwords:
      new_query += ' ' + w
      continue
    try:
      i = index.getLexicon()[w].getDocumentFrequency()
      print('document freq of ' + w +": " + str(i))
    except:
      i = 0
      print(w + ' is not present in the index')

    synonyms = get_manually_synonyms(w)

    try:
      if len(synonyms) == 0:
        new_query += ' ' + w
        continue
    except:
        new_query += ' ' + w
        continue

    d = {}
    for s in synonyms:
      try:
        i_s = index.getLexicon()[ps.stem(s)].getDocumentFrequency()
      except:
        continue
      if i_s > i:
          d[s] = i_s

    if len(d) > 0:
      max_idf_synonym = max(d.items(), key=operator.itemgetter(1))[0]
      print('the synonym chosen is ' + max_idf_synonym)
      new_query += ' ' + max_idf_synonym
    else:
      new_query += ' ' + w
      
  print('The original query was: ' + q["query"])
  print('The new query is: ' + new_query)
  return new_query

# %% [markdown]
# Here are listed all the improvement proposed. All of them are pipelines where the transformation of the queries is then followed by the baseline

# %%
abbreviations = pt.apply.query(replace_abbreviations) >> bm25

# %%
replace_with_synonyms = pt.apply.query(replace_with_high_idf_synonym) >> bm25

# %%
replace_with_synonyms_only_if_null = pt.apply.query(replace_with_high_idf_synonym_only_if_not_in_passages) >> bm25

# %%
replace_with_synonyms_manual = pt.apply.query(replace_with_high_idf_synonym_manual) >> bm25

# %%
pt.Experiment(
  [bm25, abbreviations],
  dataset.get_topics("test-2019"), 
  dataset.get_qrels("test-2019"),
  eval_metrics=["ndcg", "map", "recip_rank"], 
  perquery = "true",
  filter_by_qrels = "true"
)
# Out:
# The original query was: do goldfish grow
# The new query is: do goldfish grow
# The original query was: what is wifi vs bluetooth
# The new query is: what is wifi vs bluetooth
# The original query was: why did the us volunterilay enter ww1
# The new query is: why did the united states volunterilay enter world war 1
# The original query was: definition declaratory judgment
# The new query is: definition declaratory judgment
# The original query was: right pelvic pain causes
# The new query is: right pelvic pain causes
# The original query was: what are the social determinants of health
# The new query is: what are the social determinants of health
# The original query was: does legionella pneumophila cause pneumonia
# The new query is: does legionella pneumophila cause pneumonia
# The original query was: how is the weather in jamaica
# The new query is: how is the weather in jamaica
# The original query was: types of dysarthria from cerebral palsy
# The new query is: types of dysarthria from cerebral palsy
# The original query was: who is robert gray
# The new query is: who is robert gray
# The original query was: what types of food can you cook sous vide
# The new query is: what types of food can you cook sous vide
# The original query was: how long is life cycle of flea
# The new query is: how long is life cycle of flea
# The original query was: what can contour plowing reduce
# The new query is: what can contour plowing reduce
# The original query was: when was the salvation army founded
# The new query is: when was the salvation army founded
# The original query was: what is a active margin
# The new query is: what is a active margin
# The original query was: difference between rn and bsn
# The new query is: difference between registered nurse and bachelor of science in nursing
# The original query was: medicare s definition of mechanical ventilation
# The new query is: medicare s definition of mechanical ventilation
# The original query was: how to find the midsegment of a trapezoid
# The new query is: how to find the midsegment of a trapezoid
# The original query was: what is an aml surveillance analyst
# The new query is: what is an aml surveillance analyst
# The original query was: what is the daily life of thai people
# The new query is: what is the daily life of thai people
# The original query was: definition of a sigmet
# The new query is: definition of a sigmet
# The original query was: cost of interior concrete flooring
# The new query is: cost of interior concrete flooring
# The original query was: what is the most popular food in switzerland
# The new query is: what is the most popular food in switzerland
# The original query was: how are some sharks warm blooded
# The new query is: how are some sharks warm blooded
# The original query was: what is durable medical equipment consist of
# The new query is: what is durable medical equipment consist of
# The original query was: exons definition biology
# The new query is: exons definition biology
# The original query was: define visceral
# The new query is: define visceral
# The original query was: tracheids are part of
# The new query is: tracheids are part of
# The original query was: rsa definition key
# The new query is: rsa definition key
# The original query was: who formed the commonwealth of independent states
# The new query is: who formed the commonwealth of independent states
# The original query was: causes of left ventricular hypertrophy
# The new query is: causes of left ventricular hypertrophy
# The original query was: lps laws definition
# The new query is: lanterman petris short laws definition
# The original query was: what are the three percenters
# The new query is: what are the three percenters
# The original query was: causes of military suicide
# The new query is: causes of military suicide
# The original query was: what is theraderm used for
# The new query is: what is theraderm used for
# The original query was: what is famvir prescribed for
# The new query is: what is famvir prescribed for
# The original query was: anthropological definition of environment
# The new query is: anthropological definition of environment
# The original query was: axon terminals or synaptic knob definition
# The new query is: axon terminals or synaptic knob definition
# The original query was: is cdg airport in main paris
# The new query is: is cdg airport in main paris
# The original query was: example of monotonic function
# The new query is: example of monotonic function
# The original query was: what is physical description of spruce
# The new query is: what is physical description of spruce
# The original query was: hydrogen is a liquid below what temperature
# The new query is: hydrogen is a liquid below what temperature
# The original query was: difference between a mcdouble and a double cheeseburger
# The new query is: difference between a mcdouble and a double cheeseburger
#                                                   name      qid     measure  \
# 27                                            BR(BM25)  1037798         map
# 28                                            BR(BM25)  1037798  recip_rank
# 29                                            BR(BM25)  1037798        ndcg
# 63                                            BR(BM25)   104861         map
# 64                                            BR(BM25)   104861  recip_rank
# ..                                                 ...      ...         ...
# 160  Compose(<pyterrier.transformer.ApplyQueryTrans...   915593  recip_rank
# 161  Compose(<pyterrier.transformer.ApplyQueryTrans...   915593        ndcg
# 168  Compose(<pyterrier.transformer.ApplyQueryTrans...   962179         map
# 169  Compose(<pyterrier.transformer.ApplyQueryTrans...   962179  recip_rank
# 170  Compose(<pyterrier.transformer.ApplyQueryTrans...   962179        ndcg
#
#         value
# 27   0.109533
# 28   0.333333
# 29   0.433398
# 63   0.356779
# 64   1.000000
# ..        ...
# 160  1.000000
# 161  0.728993
# 168  0.058701
# 169  0.025000
# 170  0.400428
#
# [258 rows x 4 columns]

# %%
pt.Experiment(
  [bm25, abbreviations, replace_with_synonyms, replace_with_synonyms_only_if_null, replace_with_synonyms_manual],
  dataset.get_topics("test-2019"), 
  dataset.get_qrels("test-2019"),
  eval_metrics=["ndcg", "map", "recip_rank"], 
  filter_by_qrels = "true",
  baseline=0,
  round=3,
  names = ["bm25","abbreviations", "replace with synonyms", "replace only if null", "replace manually"]
)
# Out:
# The original query was: do goldfish grow
# The new query is: do goldfish grow
# The original query was: what is wifi vs bluetooth
# The new query is: what is wifi vs bluetooth
# The original query was: why did the us volunterilay enter ww1
# The new query is: why did the united states volunterilay enter world war 1
# The original query was: definition declaratory judgment
# The new query is: definition declaratory judgment
# The original query was: right pelvic pain causes
# The new query is: right pelvic pain causes
# The original query was: what are the social determinants of health
# The new query is: what are the social determinants of health
# The original query was: does legionella pneumophila cause pneumonia
# The new query is: does legionella pneumophila cause pneumonia
# The original query was: how is the weather in jamaica
# The new query is: how is the weather in jamaica
# The original query was: types of dysarthria from cerebral palsy
# The new query is: types of dysarthria from cerebral palsy
# The original query was: who is robert gray
# The new query is: who is robert gray
# The original query was: what types of food can you cook sous vide
# The new query is: what types of food can you cook sous vide
# The original query was: how long is life cycle of flea
# The new query is: how long is life cycle of flea
# The original query was: what can contour plowing reduce
# The new query is: what can contour plowing reduce
# The original query was: when was the salvation army founded
# The new query is: when was the salvation army founded
# The original query was: what is a active margin
# The new query is: what is a active margin
# The original query was: difference between rn and bsn
# The new query is: difference between registered nurse and bachelor of science in nursing
# The original query was: medicare s definition of mechanical ventilation
# The new query is: medicare s definition of mechanical ventilation
# The original query was: how to find the midsegment of a trapezoid
# The new query is: how to find the midsegment of a trapezoid
# The original query was: what is an aml surveillance analyst
# The new query is: what is an aml surveillance analyst
# The original query was: what is the daily life of thai people
# The new query is: what is the daily life of thai people
# The original query was: definition of a sigmet
# The new query is: definition of a sigmet
# The original query was: cost of interior concrete flooring
# The new query is: cost of interior concrete flooring
# The original query was: what is the most popular food in switzerland
# The new query is: what is the most popular food in switzerland
# The original query was: how are some sharks warm blooded
# The new query is: how are some sharks warm blooded
# The original query was: what is durable medical equipment consist of
# The new query is: what is durable medical equipment consist of
# The original query was: exons definition biology
# The new query is: exons definition biology
# The original query was: define visceral
# The new query is: define visceral
# The original query was: tracheids are part of
# The new query is: tracheids are part of
# The original query was: rsa definition key
# The new query is: rsa definition key
# The original query was: who formed the commonwealth of independent states
# The new query is: who formed the commonwealth of independent states
# The original query was: causes of left ventricular hypertrophy
# The new query is: causes of left ventricular hypertrophy
# The original query was: lps laws definition
# The new query is: lanterman petris short laws definition
# The original query was: what are the three percenters
# The new query is: what are the three percenters
# The original query was: causes of military suicide
# The new query is: causes of military suicide
# The original query was: what is theraderm used for
# The new query is: what is theraderm used for
# The original query was: what is famvir prescribed for
# The new query is: what is famvir prescribed for
# The original query was: anthropological definition of environment
# The new query is: anthropological definition of environment
# The original query was: axon terminals or synaptic knob definition
# The new query is: axon terminals or synaptic knob definition
# The original query was: is cdg airport in main paris
# The new query is: is cdg airport in main paris
# The original query was: example of monotonic function
# The new query is: example of monotonic function
# The original query was: what is physical description of spruce
# The new query is: what is physical description of spruce
# The original query was: hydrogen is a liquid below what temperature
# The new query is: hydrogen is a liquid below what temperature
# The original query was: difference between a mcdouble and a double cheeseburger
# The new query is: difference between a mcdouble and a double cheeseburger
# document freq of goldfish: 1405
# No synonyms have been found for goldfish
# document freq of grow: 119950
# No synonyms have been found for grow
# The original query was: do goldfish grow
# The new query is:  do goldfish grow
# document freq of what: 1334
# No synonyms have been found for what
# document freq of wifi: 4504
# No synonyms have been found for wifi
# vs is not present in the index
# No synonyms have been found for vs
# document freq of bluetooth: 4737
# No synonyms have been found for bluetooth
# The original query was: what is wifi vs bluetooth
# The new query is:  what is wifi vs bluetooth
# document freq of why: 97
# No synonyms have been found for why
# document freq of did: 4
# No synonyms have been found for did
# document freq of the: 60
# No synonyms have been found for the
# document freq of us: 394109
# No synonyms have been found for us
# volunterilay is not present in the index
# No synonyms have been found for volunterilay
# document freq of enter: 105770
# No synonyms have been found for enter
# document freq of ww1: 426
# No synonyms have been found for ww1
# The original query was: why did the us volunterilay enter ww1
# The new query is:  why did the us volunterilay enter ww1
# definition is not present in the index
# No synonyms have been found for definition
# declaratory is not present in the index
# No synonyms have been found for declaratory
# document freq of judgment: 11420
#
#  synonyms for: judgment:
# ['assays', 'breakdowns', 'dissections', 'dissolutions', 'divisions', 'inquiries', 'investigations', 'partitions', 'reasonings', 'resolutions', 'scrutinies', 'searches', 'separations', 'studies', 'subdivisions', 'tests']
# The synonym chosen is tests
# The original query was: definition declaratory judgment
# The new query is:  definition declaratory tests
# document freq of right: 267411
# No synonyms have been found for right
# document freq of pelvic: 7531
# No synonyms have been found for pelvic
# document freq of pain: 159923
# No synonyms have been found for pain
# document freq of causes: 1
# No synonyms have been found for causes
# The original query was: right pelvic pain causes
# The new query is:  right pelvic pain causes
# document freq of what: 1334
# No synonyms have been found for what
# document freq of the: 60
# No synonyms have been found for the
# document freq of social: 92296
# No synonyms have been found for social
# determinants is not present in the index
# No synonyms have been found for determinants
# document freq of of: 132
# No synonyms have been found for of
# document freq of health: 206860
#
#  synonyms for: health:
# ['aspect', 'build', 'constitution', 'fettle', 'form', 'health', 'kilter', 'mint', 'order', 'phase', 'repair', 'state', 'status', 'tone', 'trim']
# The synonym chosen is state
# The original query was: what are the social determinants of health
# The new query is:  what are the social determinants of state
# document freq of legionella: 352
# No synonyms have been found for legionella
# document freq of pneumophila: 138
# No synonyms have been found for pneumophila
# document freq of cause: 1
# No synonyms have been found for cause
# document freq of pneumonia: 9012
# No synonyms have been found for pneumonia
# The original query was: does legionella pneumophila cause pneumonia
# The new query is:  does legionella pneumophila cause pneumonia
# document freq of how: 1125
# No synonyms have been found for how
# document freq of the: 60
# No synonyms have been found for the
# document freq of weather: 90974
# No synonyms have been found for weather
# document freq of jamaica: 3856
# No synonyms have been found for jamaica
# The original query was: how is the weather in jamaica
# The new query is:  how is the weather in jamaica
# document freq of types: 2
# No synonyms have been found for types
# document freq of of: 132
# No synonyms have been found for of
# document freq of dysarthria: 262
# No synonyms have been found for dysarthria
# document freq of from: 19
#
#  synonyms for: from:
# ['after', 'afterward', 'ago', 'already', 'as', 'because', 'considering', 'for', 'from', 'hence', 'later', 'now', 'past', 'subsequently', 'therefore', 'whereas']
# The synonym chosen is now
# document freq of cerebral: 4
# No synonyms have been found for cerebral
# palsy is not present in the index
# No synonyms have been found for palsy
# The original query was: types of dysarthria from cerebral palsy
# The new query is:  types of dysarthria now cerebral palsy
# document freq of who: 482512
# No synonyms have been found for who
# document freq of robert: 24177
# No synonyms have been found for robert
# document freq of gray: 28
# No synonyms have been found for gray
# The original query was: who is robert gray
# The new query is:  who is robert gray
# document freq of what: 1334
# No synonyms have been found for what
# document freq of types: 2
# No synonyms have been found for types
# document freq of of: 132
# No synonyms have been found for of
# document freq of food: 246627
#
#  synonyms for: food:
# ['beef', 'brawn', 'cells', 'corpuscles', 'fat', 'fatness', 'flesh and blood', 'food', 'meat', 'muscle', 'plasm', 'plasma', 'protoplasm', 'sinews', 'thews', 'weight']
# document freq of can: 1640755
# No synonyms have been found for can
# document freq of you: 63
# No synonyms have been found for you
# document freq of cook: 96667
# No synonyms have been found for cook
# document freq of sous: 55
# No synonyms have been found for sous
# document freq of vide: 614
# No synonyms have been found for vide
# The original query was: what types of food can you cook sous vide
# The new query is:  what types of food can you cook sous vide
# document freq of how: 1125
# No synonyms have been found for how
# document freq of long: 288233
# No synonyms have been found for long
# document freq of life: 212114
# No synonyms have been found for life
# cycle is not present in the index
# No synonyms have been found for cycle
# document freq of of: 132
# No synonyms have been found for of
# document freq of flea: 5449
# No synonyms have been found for flea
# The original query was: how long is life cycle of flea
# The new query is:  how long is life cycle of flea
# document freq of what: 1334
# No synonyms have been found for what
# document freq of can: 1640755
# No synonyms have been found for can
# document freq of contour: 2733
# No synonyms have been found for contour
# plowing is not present in the index
# No synonyms have been found for plowing
# reduce is not present in the index
# No synonyms have been found for reduce
# The original query was: what can contour plowing reduce
# The new query is:  what can contour plowing reduce
# document freq of when: 20
# No synonyms have been found for when
# was is not present in the index
#
#  synonyms for: was:
# ['depart', 'die', 'discontinue', 'forsake', 'give up', 'go', 'halt', 'idle', 'leave', 'lose', 'pass', 'quit', 'refuse', 'reject', 'stop']
# The synonym chosen is leave
# document freq of the: 60
# No synonyms have been found for the
# salvation is not present in the index
# No synonyms have been found for salvation
# army is not present in the index
# No synonyms have been found for army
# founded is not present in the index
# No synonyms have been found for founded
# The original query was: when was the salvation army founded
# The new query is:  when leave the salvation army founded
# document freq of what: 1334
# No synonyms have been found for what
# document freq of a: 1309
# No synonyms have been found for a
# document freq of active: 1
#
#  synonyms for: active:
# ['inoperative', 'unmovable', ".css-j1gz4q{background:none;border:none;cursor:pointer;padding:0;border-radius:100px;font-size:16px;font-weight:inherit;line-height:1;text-align:left;-webkit-transition:all 0.25s ease-in-out;transition:all 0.25s ease-in-out;position:relative;background-color:#E1E1E1;color:#1A1A1A;padding:8px 16px;}.css-j1gz4q:before{border:4px solid #0046BE;border-radius:100px;bottom:-8px;content:' ';left:-8px;opacity:0;position:absolute;right:-8px;top:-8px;-webkit-transition:all 0.25s ease-in-out;transition:all 0.25s ease-in-out;}.css-j1gz4q:focus{outline:none;}.css-j1gz4q:focus:not(:hover):not(:active):not([disabled]):before{opacity:1;}.css-j1gz4q:hover:not([disabled]){-webkit-transform:scale(1.05);-moz-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);}.css-j1gz4q:active:not([disabled]){background-color:#E1E1E1;-webkit-transform:scale(1);-moz-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}.css-j1gz4q[disabled]{background-color:#E1E1E1;color:#767676;cursor:not-allowed;}.css-j1gz4q[loading]{color:#E1E1E1;}unworking", 'disinterested', 'dormant', 'idle', 'immobile', 'inactive', 'indifferent', 'inert', 'lazy', 'quiescent', 'quiet', 'sluggish']
# The synonym chosen is quiet
# document freq of margin: 15540
# No synonyms have been found for margin
# The original query was: what is a active margin
# The new query is:  what is a quiet margin
# document freq of difference: 2
# No synonyms have been found for difference
# document freq of between: 47
# No synonyms have been found for between
# document freq of rn: 7583
# No synonyms have been found for rn
# document freq of and: 2149
# No synonyms have been found for and
# document freq of bsn: 2077
# No synonyms have been found for bsn
# The original query was: difference between rn and bsn
# The new query is:  difference between rn and bsn
# document freq of medicare: 1
# No synonyms have been found for medicare
# s is not present in the index
# No synonyms have been found for s
# definition is not present in the index
# No synonyms have been found for definition
# document freq of of: 132
# No synonyms have been found for of
# document freq of mechanical: 2
# No synonyms have been found for mechanical
# ventilation is not present in the index
#
#  synonyms for: ventilation:
# ['blast', 'breath', 'breeze', 'draft', 'heavens', 'ozone', 'puff', 'sky', 'stratosphere', 'troposphere', 'ventilation', 'waft', 'whiff', 'wind', 'zephyr']
# The synonym chosen is breath
# The original query was: medicare s definition of mechanical ventilation
# The new query is:  medicare s definition of mechanical breath
# document freq of how: 1125
# No synonyms have been found for how
# document freq of to: 1255
# No synonyms have been found for to
# document freq of find: 310530
# No synonyms have been found for find
# document freq of the: 60
# No synonyms have been found for the
# midsegment is not present in the index
# No synonyms have been found for midsegment
# document freq of of: 132
# No synonyms have been found for of
# document freq of a: 1309
# No synonyms have been found for a
# document freq of trapezoid: 749
# No synonyms have been found for trapezoid
# The original query was: how to find the midsegment of a trapezoid
# The new query is:  how to find the midsegment of a trapezoid
# document freq of what: 1334
# No synonyms have been found for what
# document freq of an: 1998
# No synonyms have been found for an
# document freq of aml: 628
# No synonyms have been found for aml
# surveillance is not present in the index
# No synonyms have been found for surveillance
# document freq of analyst: 10689
# No synonyms have been found for analyst
# The original query was: what is an aml surveillance analyst
# The new query is:  what is an aml surveillance analyst
# document freq of what: 1334
# No synonyms have been found for what
# document freq of the: 60
# No synonyms have been found for the
# daily is not present in the index
# No synonyms have been found for daily
# document freq of life: 212114
# No synonyms have been found for life
# document freq of of: 132
# No synonyms have been found for of
# document freq of thai: 2771
# No synonyms have been found for thai
# document freq of people: 1
# No synonyms have been found for people
# The original query was: what is the daily life of thai people
# The new query is:  what is the daily life of thai people
# definition is not present in the index
# No synonyms have been found for definition
# document freq of of: 132
# No synonyms have been found for of
# document freq of a: 1309
# No synonyms have been found for a
# document freq of sigmet: 24
# No synonyms have been found for sigmet
# The original query was: definition of a sigmet
# The new query is:  definition of a sigmet
# document freq of cost: 281652
# No synonyms have been found for cost
# document freq of of: 132
# No synonyms have been found for of
# document freq of interior: 18109
# No synonyms have been found for interior
# concrete is not present in the index
# No synonyms have been found for concrete
# flooring is not present in the index
# No synonyms have been found for flooring
# The original query was: cost of interior concrete flooring
# The new query is:  cost of interior concrete flooring
# document freq of what: 1334
# No synonyms have been found for what
# document freq of the: 60
# No synonyms have been found for the
# document freq of most: 12
# No synonyms have been found for most
# document freq of popular: 120881
# No synonyms have been found for popular
# document freq of food: 246627
#
#  synonyms for: food:
# ['beef', 'brawn', 'cells', 'corpuscles', 'fat', 'fatness', 'flesh and blood', 'food', 'meat', 'muscle', 'plasm', 'plasma', 'protoplasm', 'sinews', 'thews', 'weight']
# document freq of switzerland: 6241
# No synonyms have been found for switzerland
# The original query was: what is the most popular food in switzerland
# The new query is:  what is the most popular food in switzerland
# document freq of how: 1125
# No synonyms have been found for how
# document freq of some: 35
# No synonyms have been found for some
# sharks is not present in the index
# No synonyms have been found for sharks
# document freq of warm: 56250
# No synonyms have been found for warm
# document freq of blooded: 9
# No synonyms have been found for blooded
# The original query was: how are some sharks warm blooded
# The new query is:  how are some sharks warm blooded
# document freq of what: 1334
# No synonyms have been found for what
# durable is not present in the index
# No synonyms have been found for durable
# document freq of medical: 10
#
#  synonyms for: medical:
# ['pharmaceutical', 'preventive', 'therapeutic', 'curative', 'disinfectant', 'narcotic', 'prophylactic', 'restorative', 'sedative', 'tonic', 'medicating', 'pathological', 'salutary']
# The synonym chosen is medicating
# equipment is not present in the index
# No synonyms have been found for equipment
# document freq of consist: 103309
# No synonyms have been found for consist
# document freq of of: 132
# No synonyms have been found for of
# The original query was: what is durable medical equipment consist of
# The new query is:  what is durable medicating equipment consist of
# exons is not present in the index
# No synonyms have been found for exons
# definition is not present in the index
# No synonyms have been found for definition
# biology is not present in the index
#
#  synonyms for: biology:
# ['cytology', 'diagnosis', 'dissection', 'division', 'embryology', 'etiology', 'examination', 'genetics', 'histology', 'inquiry', 'investigation', 'medicine', 'morphology', 'physiology', 'zoology']
# The synonym chosen is medicine
# The original query was: exons definition biology
# The new query is:  exons definition medicine
# define is not present in the index
# No synonyms have been found for define
# visceral is not present in the index
#
#  synonyms for: visceral:
# ['basic', 'deep-seated', 'emotional', 'heartfelt', 'innate', 'inner', 'instinctive', 'interior', 'internal', 'intimate', 'involuntary', 'natural', 'spontaneous', 'unthinking', 'visceral', 'viscerous']
# The synonym chosen is natural
# The original query was: define visceral
# The new query is:  define natural
# tracheids is not present in the index
# No synonyms have been found for tracheids
# document freq of part: 376430
#
#  synonyms for: part:
# ['break off', 'come between', 'disaffect', 'disunite', 'divide', 'divorce', 'estrange', 'make indifferent', 'part', 'push away', 'separate', 'set against', 'turn away', 'turn off', 'wean', 'withdraw the affections of']
# document freq of of: 132
# No synonyms have been found for of
# The original query was: tracheids are part of
# The new query is:  tracheids are part of
# document freq of rsa: 696
# No synonyms have been found for rsa
# definition is not present in the index
# No synonyms have been found for definition
# document freq of key: 179
# No synonyms have been found for key
# The original query was: rsa definition key
# The new query is:  rsa definition key
# document freq of who: 482512
# No synonyms have been found for who
# document freq of formed: 7
# No synonyms have been found for formed
# document freq of the: 60
# No synonyms have been found for the
# document freq of commonwealth: 5327
# No synonyms have been found for commonwealth
# document freq of of: 132
# No synonyms have been found for of
# document freq of independent: 2
#
#  synonyms for: independent:
# ['alien', 'apparent', 'exterior', 'extraneous', 'foreign', 'independent', 'out', 'outer', 'outermost', 'outmost', 'outward', 'over', 'peripheral', 'superficial', 'surface', 'visible']
# The synonym chosen is surface
# document freq of states: 1
# No synonyms have been found for states
# The original query was: who formed the commonwealth of independent states
# The new query is:  who formed the commonwealth of surface states
# document freq of causes: 1
# No synonyms have been found for causes
# document freq of of: 132
# No synonyms have been found for of
# document freq of left: 115611
# No synonyms have been found for left
# document freq of ventricular: 3361
# No synonyms have been found for ventricular
# hypertrophy is not present in the index
# No synonyms have been found for hypertrophy
# The original query was: causes of left ventricular hypertrophy
# The new query is:  causes of left ventricular hypertrophy
# lps is not present in the index
# No synonyms have been found for lps
# laws is not present in the index
# No synonyms have been found for laws
# definition is not present in the index
# No synonyms have been found for definition
# The original query was: lps laws definition
# The new query is:  lps laws definition
# document freq of what: 1334
# No synonyms have been found for what
# document freq of the: 60
# No synonyms have been found for the
# document freq of three: 187
#
#  synonyms for: three:
# ['third', 'treble', 'trilateral', 'trinitarian', 'triple', 'ternate', 'triangular', 'trichotomic', 'trichotomous', 'trigonal', 'trigonous', 'trinal', 'trinary', 'tripartite']
# The synonym chosen is third
# percenters is not present in the index
# No synonyms have been found for percenters
# The original query was: what are the three percenters
# The new query is:  what are the third percenters
# document freq of causes: 1
# No synonyms have been found for causes
# document freq of of: 132
# No synonyms have been found for of
# military is not present in the index
# No synonyms have been found for military
# suicide is not present in the index
# No synonyms have been found for suicide
# The original query was: causes of military suicide
# The new query is:  causes of military suicide
# document freq of what: 1334
# No synonyms have been found for what
# document freq of theraderm: 5
# No synonyms have been found for theraderm
# document freq of used: 1
# No synonyms have been found for used
# document freq of for: 26
# No synonyms have been found for for
# The original query was: what is theraderm used for
# The new query is:  what is theraderm used for
# document freq of what: 1334
# No synonyms have been found for what
# document freq of famvir: 62
# No synonyms have been found for famvir
# prescribed is not present in the index
# No synonyms have been found for prescribed
# document freq of for: 26
# No synonyms have been found for for
# The original query was: what is famvir prescribed for
# The new query is:  what is famvir prescribed for
# anthropological is not present in the index
#
#  synonyms for: anthropological:
# ['animal', 'anthropoid', 'anthropological', 'anthropomorphic', 'anthropomorphous', 'biped', 'bipedal', 'creatural', 'ethnologic', 'ethological', 'hominal', 'hominid', 'hominine', 'hominoid', 'individual', 'mortal']
# The synonym chosen is individual
# definition is not present in the index
# No synonyms have been found for definition
# document freq of of: 132
# No synonyms have been found for of
# document freq of environment: 24207
# No synonyms have been found for environment
# The original query was: anthropological definition of environment
# The new query is:  individual definition of environment
# document freq of axon: 4561
# No synonyms have been found for axon
# terminals is not present in the index
# No synonyms have been found for terminals
# document freq of or: 7430
# No synonyms have been found for or
# synaptic is not present in the index
# No synonyms have been found for synaptic
# document freq of knob: 2658
# No synonyms have been found for knob
# definition is not present in the index
# No synonyms have been found for definition
# The original query was: axon terminals or synaptic knob definition
# The new query is:  axon terminals or synaptic knob definition
# document freq of cdg: 208
# No synonyms have been found for cdg
# document freq of airport: 40222
# No synonyms have been found for airport
# document freq of main: 8692
# No synonyms have been found for main
# document freq of paris: 21
# No synonyms have been found for paris
# The original query was: is cdg airport in main paris
# The new query is:  is cdg airport in main paris
# example is not present in the index
# No synonyms have been found for example
# document freq of of: 132
# No synonyms have been found for of
# monotonic is not present in the index
# No synonyms have been found for monotonic
# document freq of function: 159918
#
#  synonyms for: function:
# ['appliance', 'appositeness', 'employment', 'exercise', 'exercising', 'function', 'germaneness', 'operation', 'pertinence', 'play', 'practice', 'purpose', 'relevance', 'usance', 'utilization', 'value']
# The original query was: example of monotonic function
# The new query is:  example of monotonic function
# document freq of what: 1334
# No synonyms have been found for what
# document freq of physical: 4
#
#  synonyms for: physical:
# ['natural', 'real', 'substantial', 'corporeal', 'gross', 'materialistic', 'objective', 'palpable', 'phenomenal', 'ponderable', 'sensible', 'solid', 'somatic', 'visible']
# The synonym chosen is natural
# description is not present in the index
#
#  synonyms for: description:
# ['announce', 'blare', 'boast', 'broadcast', 'deck', 'declare', 'depict', 'description', 'display', 'embellish', 'emblazon', 'exhibit', 'inscribe', 'proclaim', 'publish', 'show']
# The synonym chosen is show
# document freq of of: 132
# No synonyms have been found for of
# document freq of spruce: 1973
# No synonyms have been found for spruce
# The original query was: what is physical description of spruce
# The new query is:  what is natural show of spruce
# document freq of hydrogen: 24236
# No synonyms have been found for hydrogen
# document freq of a: 1309
# No synonyms have been found for a
# document freq of liquid: 58295
# No synonyms have been found for liquid
# document freq of below: 20
# No synonyms have been found for below
# document freq of what: 1334
# No synonyms have been found for what
# temperature is not present in the index
# No synonyms have been found for temperature
# The original query was: hydrogen is a liquid below what temperature
# The new query is:  hydrogen is a liquid below what temperature
# document freq of difference: 2
# No synonyms have been found for difference
# document freq of between: 47
# No synonyms have been found for between
# document freq of a: 1309
# No synonyms have been found for a
# mcdouble is not present in the index
# No synonyms have been found for mcdouble
# document freq of and: 2149
# No synonyms have been found for and
# document freq of a: 1309
# No synonyms have been found for a
# double is not present in the index
# No synonyms have been found for double
# cheeseburger is not present in the index
# No synonyms have been found for cheeseburger
# The original query was: difference between a mcdouble and a double cheeseburger
# The new query is:  difference between a mcdouble and a double cheeseburger
# document freq of goldfish: 1405. Since this word is present in the documents, it is not going to be replaced.
# document freq of grow: 119950. Since this word is present in the documents, it is not going to be replaced.
# The original query was: do goldfish grow
# The new query is:  do goldfish grow
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of wifi: 4504. Since this word is present in the documents, it is not going to be replaced.
# vs is not present in the index, so it is going to be replaced.
# No synonyms have been found for vs
# document freq of bluetooth: 4737. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what is wifi vs bluetooth
# The new query is:  what is wifi vs bluetooth
# document freq of why: 97. Since this word is present in the documents, it is not going to be replaced.
# document freq of did: 4. Since this word is present in the documents, it is not going to be replaced.
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# document freq of us: 394109. Since this word is present in the documents, it is not going to be replaced.
# volunterilay is not present in the index, so it is going to be replaced.
# No synonyms have been found for volunterilay
# document freq of enter: 105770. Since this word is present in the documents, it is not going to be replaced.
# document freq of ww1: 426. Since this word is present in the documents, it is not going to be replaced.
# The original query was: why did the us volunterilay enter ww1
# The new query is:  why did the us volunterilay enter ww1
# definition is not present in the index, so it is going to be replaced.
# No synonyms have been found for definition
# declaratory is not present in the index, so it is going to be replaced.
# No synonyms have been found for declaratory
# document freq of judgment: 11420. Since this word is present in the documents, it is not going to be replaced.
# The original query was: definition declaratory judgment
# The new query is:  definition declaratory judgment
# document freq of right: 267411. Since this word is present in the documents, it is not going to be replaced.
# document freq of pelvic: 7531. Since this word is present in the documents, it is not going to be replaced.
# document freq of pain: 159923. Since this word is present in the documents, it is not going to be replaced.
# document freq of causes: 1. Since this word is present in the documents, it is not going to be replaced.
# The original query was: right pelvic pain causes
# The new query is:  right pelvic pain causes
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# document freq of social: 92296. Since this word is present in the documents, it is not going to be replaced.
# determinants is not present in the index, so it is going to be replaced.
# No synonyms have been found for determinants
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of health: 206860. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what are the social determinants of health
# The new query is:  what are the social determinants of health
# document freq of legionella: 352. Since this word is present in the documents, it is not going to be replaced.
# document freq of pneumophila: 138. Since this word is present in the documents, it is not going to be replaced.
# document freq of cause: 1. Since this word is present in the documents, it is not going to be replaced.
# document freq of pneumonia: 9012. Since this word is present in the documents, it is not going to be replaced.
# The original query was: does legionella pneumophila cause pneumonia
# The new query is:  does legionella pneumophila cause pneumonia
# document freq of how: 1125. Since this word is present in the documents, it is not going to be replaced.
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# document freq of weather: 90974. Since this word is present in the documents, it is not going to be replaced.
# document freq of jamaica: 3856. Since this word is present in the documents, it is not going to be replaced.
# The original query was: how is the weather in jamaica
# The new query is:  how is the weather in jamaica
# document freq of types: 2. Since this word is present in the documents, it is not going to be replaced.
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of dysarthria: 262. Since this word is present in the documents, it is not going to be replaced.
# document freq of from: 19. Since this word is present in the documents, it is not going to be replaced.
# document freq of cerebral: 4. Since this word is present in the documents, it is not going to be replaced.
# palsy is not present in the index, so it is going to be replaced.
# No synonyms have been found for palsy
# The original query was: types of dysarthria from cerebral palsy
# The new query is:  types of dysarthria from cerebral palsy
# document freq of who: 482512. Since this word is present in the documents, it is not going to be replaced.
# document freq of robert: 24177. Since this word is present in the documents, it is not going to be replaced.
# document freq of gray: 28. Since this word is present in the documents, it is not going to be replaced.
# The original query was: who is robert gray
# The new query is:  who is robert gray
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of types: 2. Since this word is present in the documents, it is not going to be replaced.
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of food: 246627. Since this word is present in the documents, it is not going to be replaced.
# document freq of can: 1640755. Since this word is present in the documents, it is not going to be replaced.
# document freq of you: 63. Since this word is present in the documents, it is not going to be replaced.
# document freq of cook: 96667. Since this word is present in the documents, it is not going to be replaced.
# document freq of sous: 55. Since this word is present in the documents, it is not going to be replaced.
# document freq of vide: 614. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what types of food can you cook sous vide
# The new query is:  what types of food can you cook sous vide
# document freq of how: 1125. Since this word is present in the documents, it is not going to be replaced.
# document freq of long: 288233. Since this word is present in the documents, it is not going to be replaced.
# document freq of life: 212114. Since this word is present in the documents, it is not going to be replaced.
# cycle is not present in the index, so it is going to be replaced.
# No synonyms have been found for cycle
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of flea: 5449. Since this word is present in the documents, it is not going to be replaced.
# The original query was: how long is life cycle of flea
# The new query is:  how long is life cycle of flea
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of can: 1640755. Since this word is present in the documents, it is not going to be replaced.
# document freq of contour: 2733. Since this word is present in the documents, it is not going to be replaced.
# plowing is not present in the index, so it is going to be replaced.
# No synonyms have been found for plowing
# reduce is not present in the index, so it is going to be replaced.
# No synonyms have been found for reduce
# The original query was: what can contour plowing reduce
# The new query is:  what can contour plowing reduce
# document freq of when: 20. Since this word is present in the documents, it is not going to be replaced.
# was is not present in the index, so it is going to be replaced.
#
#  synonyms for: was:
# ['depart', 'die', 'discontinue', 'forsake', 'give up', 'go', 'halt', 'idle', 'leave', 'lose', 'pass', 'quit', 'refuse', 'reject', 'stop']
# The synonym chosen is leave
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# salvation is not present in the index, so it is going to be replaced.
# No synonyms have been found for salvation
# army is not present in the index, so it is going to be replaced.
# No synonyms have been found for army
# founded is not present in the index, so it is going to be replaced.
# No synonyms have been found for founded
# The original query was: when was the salvation army founded
# The new query is:  when leave the salvation army founded
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of a: 1309. Since this word is present in the documents, it is not going to be replaced.
# document freq of active: 1. Since this word is present in the documents, it is not going to be replaced.
# document freq of margin: 15540. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what is a active margin
# The new query is:  what is a active margin
# document freq of difference: 2. Since this word is present in the documents, it is not going to be replaced.
# document freq of between: 47. Since this word is present in the documents, it is not going to be replaced.
# document freq of rn: 7583. Since this word is present in the documents, it is not going to be replaced.
# document freq of and: 2149. Since this word is present in the documents, it is not going to be replaced.
# document freq of bsn: 2077. Since this word is present in the documents, it is not going to be replaced.
# The original query was: difference between rn and bsn
# The new query is:  difference between rn and bsn
# document freq of medicare: 1. Since this word is present in the documents, it is not going to be replaced.
# s is not present in the index, so it is going to be replaced.
# No synonyms have been found for s
# definition is not present in the index, so it is going to be replaced.
# No synonyms have been found for definition
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of mechanical: 2. Since this word is present in the documents, it is not going to be replaced.
# ventilation is not present in the index, so it is going to be replaced.
#
#  synonyms for: ventilation:
# ['blast', 'breath', 'breeze', 'draft', 'heavens', 'ozone', 'puff', 'sky', 'stratosphere', 'troposphere', 'ventilation', 'waft', 'whiff', 'wind', 'zephyr']
# The synonym chosen is breath
# The original query was: medicare s definition of mechanical ventilation
# The new query is:  medicare s definition of mechanical breath
# document freq of how: 1125. Since this word is present in the documents, it is not going to be replaced.
# document freq of to: 1255. Since this word is present in the documents, it is not going to be replaced.
# document freq of find: 310530. Since this word is present in the documents, it is not going to be replaced.
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# midsegment is not present in the index, so it is going to be replaced.
# No synonyms have been found for midsegment
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of a: 1309. Since this word is present in the documents, it is not going to be replaced.
# document freq of trapezoid: 749. Since this word is present in the documents, it is not going to be replaced.
# The original query was: how to find the midsegment of a trapezoid
# The new query is:  how to find the midsegment of a trapezoid
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of an: 1998. Since this word is present in the documents, it is not going to be replaced.
# document freq of aml: 628. Since this word is present in the documents, it is not going to be replaced.
# surveillance is not present in the index, so it is going to be replaced.
# No synonyms have been found for surveillance
# document freq of analyst: 10689. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what is an aml surveillance analyst
# The new query is:  what is an aml surveillance analyst
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# daily is not present in the index, so it is going to be replaced.
# No synonyms have been found for daily
# document freq of life: 212114. Since this word is present in the documents, it is not going to be replaced.
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of thai: 2771. Since this word is present in the documents, it is not going to be replaced.
# document freq of people: 1. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what is the daily life of thai people
# The new query is:  what is the daily life of thai people
# definition is not present in the index, so it is going to be replaced.
# No synonyms have been found for definition
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of a: 1309. Since this word is present in the documents, it is not going to be replaced.
# document freq of sigmet: 24. Since this word is present in the documents, it is not going to be replaced.
# The original query was: definition of a sigmet
# The new query is:  definition of a sigmet
# document freq of cost: 281652. Since this word is present in the documents, it is not going to be replaced.
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of interior: 18109. Since this word is present in the documents, it is not going to be replaced.
# concrete is not present in the index, so it is going to be replaced.
# No synonyms have been found for concrete
# flooring is not present in the index, so it is going to be replaced.
# No synonyms have been found for flooring
# The original query was: cost of interior concrete flooring
# The new query is:  cost of interior concrete flooring
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# document freq of most: 12. Since this word is present in the documents, it is not going to be replaced.
# document freq of popular: 120881. Since this word is present in the documents, it is not going to be replaced.
# document freq of food: 246627. Since this word is present in the documents, it is not going to be replaced.
# document freq of switzerland: 6241. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what is the most popular food in switzerland
# The new query is:  what is the most popular food in switzerland
# document freq of how: 1125. Since this word is present in the documents, it is not going to be replaced.
# document freq of some: 35. Since this word is present in the documents, it is not going to be replaced.
# sharks is not present in the index, so it is going to be replaced.
# No synonyms have been found for sharks
# document freq of warm: 56250. Since this word is present in the documents, it is not going to be replaced.
# document freq of blooded: 9. Since this word is present in the documents, it is not going to be replaced.
# The original query was: how are some sharks warm blooded
# The new query is:  how are some sharks warm blooded
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# durable is not present in the index, so it is going to be replaced.
# No synonyms have been found for durable
# document freq of medical: 10. Since this word is present in the documents, it is not going to be replaced.
# equipment is not present in the index, so it is going to be replaced.
# No synonyms have been found for equipment
# document freq of consist: 103309. Since this word is present in the documents, it is not going to be replaced.
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what is durable medical equipment consist of
# The new query is:  what is durable medical equipment consist of
# exons is not present in the index, so it is going to be replaced.
# No synonyms have been found for exons
# definition is not present in the index, so it is going to be replaced.
# No synonyms have been found for definition
# biology is not present in the index, so it is going to be replaced.
#
#  synonyms for: biology:
# ['cytology', 'diagnosis', 'dissection', 'division', 'embryology', 'etiology', 'examination', 'genetics', 'histology', 'inquiry', 'investigation', 'medicine', 'morphology', 'physiology', 'zoology']
# The synonym chosen is medicine
# The original query was: exons definition biology
# The new query is:  exons definition medicine
# define is not present in the index, so it is going to be replaced.
# No synonyms have been found for define
# visceral is not present in the index, so it is going to be replaced.
#
#  synonyms for: visceral:
# ['basic', 'deep-seated', 'emotional', 'heartfelt', 'innate', 'inner', 'instinctive', 'interior', 'internal', 'intimate', 'involuntary', 'natural', 'spontaneous', 'unthinking', 'visceral', 'viscerous']
# The synonym chosen is natural
# The original query was: define visceral
# The new query is:  define natural
# tracheids is not present in the index, so it is going to be replaced.
# No synonyms have been found for tracheids
# document freq of part: 376430. Since this word is present in the documents, it is not going to be replaced.
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# The original query was: tracheids are part of
# The new query is:  tracheids are part of
# document freq of rsa: 696. Since this word is present in the documents, it is not going to be replaced.
# definition is not present in the index, so it is going to be replaced.
# No synonyms have been found for definition
# document freq of key: 179. Since this word is present in the documents, it is not going to be replaced.
# The original query was: rsa definition key
# The new query is:  rsa definition key
# document freq of who: 482512. Since this word is present in the documents, it is not going to be replaced.
# document freq of formed: 7. Since this word is present in the documents, it is not going to be replaced.
# document freq of the: 60. Since this word is present in the documents, it is not going to be replaced.
# document freq of commonwealth: 5327. Since this word is present in the documents, it is not going to be replaced.
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of independent: 2. Since this word is present in the documents, it is not going to be replaced.
# ...
# document freq of cdg: 208. Since this word is present in the documents, it is not going to be replaced.
# document freq of airport: 40222. Since this word is present in the documents, it is not going to be replaced.
# document freq of main: 8692. Since this word is present in the documents, it is not going to be replaced.
# document freq of paris: 21. Since this word is present in the documents, it is not going to be replaced.
# The original query was: is cdg airport in main paris
# The new query is:  is cdg airport in main paris
# example is not present in the index, so it is going to be replaced.
# No synonyms have been found for example
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# monotonic is not present in the index, so it is going to be replaced.
# No synonyms have been found for monotonic
# document freq of function: 159918. Since this word is present in the documents, it is not going to be replaced.
# The original query was: example of monotonic function
# The new query is:  example of monotonic function
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# document freq of physical: 4. Since this word is present in the documents, it is not going to be replaced.
# description is not present in the index, so it is going to be replaced.
#
#  synonyms for: description:
# ['announce', 'blare', 'boast', 'broadcast', 'deck', 'declare', 'depict', 'description', 'display', 'embellish', 'emblazon', 'exhibit', 'inscribe', 'proclaim', 'publish', 'show']
# The synonym chosen is show
# document freq of of: 132. Since this word is present in the documents, it is not going to be replaced.
# document freq of spruce: 1973. Since this word is present in the documents, it is not going to be replaced.
# The original query was: what is physical description of spruce
# The new query is:  what is physical show of spruce
# document freq of hydrogen: 24236. Since this word is present in the documents, it is not going to be replaced.
# document freq of a: 1309. Since this word is present in the documents, it is not going to be replaced.
# document freq of liquid: 58295. Since this word is present in the documents, it is not going to be replaced.
# document freq of below: 20. Since this word is present in the documents, it is not going to be replaced.
# document freq of what: 1334. Since this word is present in the documents, it is not going to be replaced.
# temperature is not present in the index, so it is going to be replaced.
# No synonyms have been found for temperature
# The original query was: hydrogen is a liquid below what temperature
# The new query is:  hydrogen is a liquid below what temperature
# document freq of difference: 2. Since this word is present in the documents, it is not going to be replaced.
# document freq of between: 47. Since this word is present in the documents, it is not going to be replaced.
# document freq of a: 1309. Since this word is present in the documents, it is not going to be replaced.
# mcdouble is not present in the index, so it is going to be replaced.
# No synonyms have been found for mcdouble
# document freq of and: 2149. Since this word is present in the documents, it is not going to be replaced.
# document freq of a: 1309. Since this word is present in the documents, it is not going to be replaced.
# double is not present in the index, so it is going to be replaced.
# No synonyms have been found for double
# cheeseburger is not present in the index, so it is going to be replaced.
# No synonyms have been found for cheeseburger
# The original query was: difference between a mcdouble and a double cheeseburger
# The new query is:  difference between a mcdouble and a double cheeseburger
# document freq of goldfish: 1405
# document freq of grow: 119950
# The original query was: do goldfish grow
# The new query is:  do goldfish grow
# document freq of what: 1334
# document freq of wifi: 4504
# vs is not present in the index
# document freq of bluetooth: 4737
# The original query was: what is wifi vs bluetooth
# The new query is:  what is wifi vs bluetooth
# document freq of why: 97
# document freq of did: 4
# document freq of the: 60
# document freq of us: 394109
# volunterilay is not present in the index
# document freq of enter: 105770
# document freq of ww1: 426
# The original query was: why did the us volunterilay enter ww1
# The new query is:  why did the us volunterilay enter ww1
# definition is not present in the index
# declaratory is not present in the index
# document freq of judgment: 11420
# The original query was: definition declaratory judgment
# The new query is:  definition declaratory judgment
# document freq of right: 267411
# document freq of pelvic: 7531
# the synonym chosen is stomach
# document freq of pain: 159923
# document freq of causes: 1
# The original query was: right pelvic pain causes
# The new query is:  right stomach pain causes
# document freq of what: 1334
# document freq of the: 60
# document freq of social: 92296
# determinants is not present in the index
# document freq of of: 132
# document freq of health: 206860
# The original query was: what are the social determinants of health
# The new query is:  what are the social determinants of health
# document freq of legionella: 352
# document freq of pneumophila: 138
# document freq of cause: 1
# document freq of pneumonia: 9012
# The original query was: does legionella pneumophila cause pneumonia
# The new query is:  does legionella pneumophila cause pneumonia
# document freq of how: 1125
# document freq of the: 60
# document freq of weather: 90974
# document freq of jamaica: 3856
# The original query was: how is the weather in jamaica
# The new query is:  how is the weather in jamaica
# document freq of types: 2
# document freq of of: 132
# document freq of dysarthria: 262
# document freq of from: 19
# document freq of cerebral: 4
# the synonym chosen is brainy
# palsy is not present in the index
# The original query was: types of dysarthria from cerebral palsy
# The new query is:  types of dysarthria from brainy palsy
# document freq of who: 482512
# document freq of robert: 24177
# document freq of gray: 28
# The original query was: who is robert gray
# The new query is:  who is robert gray
# document freq of what: 1334
# document freq of types: 2
# document freq of of: 132
# document freq of food: 246627
# document freq of can: 1640755
# document freq of you: 63
# document freq of cook: 96667
# document freq of sous: 55
# document freq of vide: 614
# The original query was: what types of food can you cook sous vide
# The new query is:  what types of food can you cook sous vide
# document freq of how: 1125
# document freq of long: 288233
# document freq of life: 212114
# cycle is not present in the index
# document freq of of: 132
# document freq of flea: 5449
# The original query was: how long is life cycle of flea
# The new query is:  how long is life cycle of flea
# document freq of what: 1334
# document freq of can: 1640755
# document freq of contour: 2733
# plowing is not present in the index
# reduce is not present in the index
# The original query was: what can contour plowing reduce
# The new query is:  what can contour plowing reduce
# document freq of when: 20
# was is not present in the index
# document freq of the: 60
# salvation is not present in the index
# army is not present in the index
# founded is not present in the index
# The original query was: when was the salvation army founded
# The new query is:  when was the salvation army founded
# document freq of what: 1334
# document freq of a: 1309
# document freq of active: 1
# document freq of margin: 15540
# the synonym chosen is boundary
# The original query was: what is a active margin
# The new query is:  what is a active boundary
# document freq of difference: 2
# document freq of between: 47
# document freq of rn: 7583
# document freq of and: 2149
# document freq of bsn: 2077
# The original query was: difference between rn and bsn
# The new query is:  difference between rn and bsn
# document freq of medicare: 1
# s is not present in the index
# definition is not present in the index
# document freq of of: 132
# document freq of mechanical: 2
# ventilation is not present in the index
# The original query was: medicare s definition of mechanical ventilation
# The new query is:  medicare s definition of mechanical ventilation
# document freq of how: 1125
# document freq of to: 1255
# document freq of find: 310530
# document freq of the: 60
# midsegment is not present in the index
# document freq of of: 132
# document freq of a: 1309
# document freq of trapezoid: 749
# The original query was: how to find the midsegment of a trapezoid
# The new query is:  how to find the midsegment of a trapezoid
# document freq of what: 1334
# document freq of an: 1998
# document freq of aml: 628
# surveillance is not present in the index
# document freq of analyst: 10689
# The original query was: what is an aml surveillance analyst
# The new query is:  what is an aml surveillance analyst
# document freq of what: 1334
# document freq of the: 60
# daily is not present in the index
# document freq of life: 212114
# document freq of of: 132
# document freq of thai: 2771
# the synonym chosen is thailand
# document freq of people: 1
# The original query was: what is the daily life of thai people
# The new query is:  what is the daily life of thailand people
# definition is not present in the index
# document freq of of: 132
# document freq of a: 1309
# document freq of sigmet: 24
# The original query was: definition of a sigmet
# The new query is:  definition of a sigmet
# document freq of cost: 281652
# document freq of of: 132
# document freq of interior: 18109
# concrete is not present in the index
# flooring is not present in the index
# The original query was: cost of interior concrete flooring
# The new query is:  cost of interior concrete flooring
# document freq of what: 1334
# document freq of the: 60
# document freq of most: 12
# document freq of popular: 120881
# document freq of food: 246627
# document freq of switzerland: 6241
# The original query was: what is the most popular food in switzerland
# The new query is:  what is the most popular food in switzerland
# document freq of how: 1125
# document freq of some: 35
# sharks is not present in the index
# document freq of warm: 56250
# document freq of blooded: 9
# The original query was: how are some sharks warm blooded
# The new query is:  how are some sharks warm blooded
# document freq of what: 1334
# durable is not present in the index
# document freq of medical: 10
# equipment is not present in the index
# document freq of consist: 103309
# document freq of of: 132
# The original query was: what is durable medical equipment consist of
# The new query is:  what is durable medical equipment consist of
# exons is not present in the index
# definition is not present in the index
# biology is not present in the index
# The original query was: exons definition biology
# The new query is:  exons definition biology
# define is not present in the index
# visceral is not present in the index
# the synonym chosen is internal
# The original query was: define visceral
# The new query is:  define internal
# tracheids is not present in the index
# document freq of part: 376430
# document freq of of: 132
# The original query was: tracheids are part of
# The new query is:  tracheids are part of
# document freq of rsa: 696
# definition is not present in the index
# document freq of key: 179
# The original query was: rsa definition key
# The new query is:  rsa definition key
# document freq of who: 482512
# document freq of formed: 7
# document freq of the: 60
# document freq of commonwealth: 5327
# document freq of of: 132
# document freq of independent: 2
# document freq of states: 1
# The original query was: who formed the commonwealth of independent states
# The new query is:  who formed the commonwealth of independent states
# document freq of causes: 1
# document freq of of: 132
# document freq of left: 115611
# document freq of ventricular: 3361
# hypertrophy is not present in the index
# The original query was: causes of left ventricular hypertrophy
# The new query is:  causes of left ventricular hypertrophy
# lps is not present in the index
# laws is not present in the index
# definition is not present in the index
# The original query was: lps laws definition
# The new query is:  lps laws definition
# document freq of what: 1334
# document freq of the: 60
# document freq of three: 187
# percenters is not present in the index
# The original query was: what are the three percenters
# The new query is:  what are the three percenters
# document freq of causes: 1
# document freq of of: 132
# military is not present in the index
# suicide is not present in the index
# The original query was: causes of military suicide
# The new query is:  causes of military suicide
# document freq of what: 1334
# document freq of theraderm: 5
# document freq of used: 1
# document freq of for: 26
# The original query was: what is theraderm used for
# The new query is:  what is theraderm used for
# document freq of what: 1334
# document freq of famvir: 62
# prescribed is not present in the index
# document freq of for: 26
# The original query was: what is famvir prescribed for
# The new query is:  what is famvir prescribed for
# anthropological is not present in the index
# definition is not present in the index
# document freq of of: 132
# document freq of environment: 24207
# The original query was: anthropological definition of environment
# The new query is:  anthropological definition of environment
# document freq of axon: 4561
# terminals is not present in the index
# document freq of or: 7430
# synaptic is not present in the index
# document freq of knob: 2658
# definition is not present in the index
# The original query was: axon terminals or synaptic knob definition
# The new query is:  axon terminals or synaptic knob definition
# document freq of cdg: 208
# document freq of airport: 40222
# document freq of main: 8692
# document freq of paris: 21
# The original query was: is cdg airport in main paris
# The new query is:  is cdg airport in main paris
# example is not present in the index
# document freq of of: 132
# monotonic is not present in the index
# document freq of function: 159918
# The original query was: example of monotonic function
# The new query is:  example of monotonic function
# document freq of what: 1334
# document freq of physical: 4
# description is not present in the index
# document freq of of: 132
# document freq of spruce: 1973
# The original query was: what is physical description of spruce
# The new query is:  what is physical description of spruce
# document freq of hydrogen: 24236
# document freq of a: 1309
# document freq of liquid: 58295
# document freq of below: 20
# document freq of what: 1334
# temperature is not present in the index
# the synonym chosen is condition
# The original query was: hydrogen is a liquid below what temperature
# The new query is:  hydrogen is a liquid below what condition
# document freq of difference: 2
# document freq of between: 47
# document freq of a: 1309
# mcdouble is not present in the index
# document freq of and: 2149
# document freq of a: 1309
# double is not present in the index
# cheeseburger is not present in the index
# The original query was: difference between a mcdouble and a double cheeseburger
# The new query is:  difference between a mcdouble and a double cheeseburger
#                     name    map  recip_rank   ndcg  map +  map -  map p-value  \
# 0                   bm25  0.370       0.795  0.593    NaN    NaN          NaN
# 1          abbreviations  0.370       0.838  0.597    2.0    1.0     0.959743
# 2  replace with synonyms  0.327       0.688  0.533    1.0   11.0     0.033763
# 3   replace only if null  0.364       0.764  0.568    2.0    4.0     0.353386
# 4       replace manually  0.362       0.701  0.574    1.0    5.0     0.336636
#
#    recip_rank +  recip_rank -  recip_rank p-value  ndcg +  ndcg -  \
# 0           NaN           NaN                 NaN     NaN     NaN
# 1           3.0           0.0            0.125346     2.0     1.0
# 2           1.0           9.0            0.036765     1.0    11.0
# 3           1.0           3.0            0.400526     1.0     5.0
# 4           0.0           5.0            0.026931     1.0     5.0
#
#    ndcg p-value
# 0           NaN
# 1      0.686425
# 2      0.014546
# 3      0.165999
# 4      0.206056

# %% [markdown]
# Here is performed the *error analysis*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
#Given a docid and a query, search if the doc id exists in top-100 ranked documents
def check_rel_doc_present(docid, qid, query, result,label):

    # Hypothesis that this if statement is always true
    if docid in list(result["docno"]):
        R = result[result["docno"]==docid]
        rank = R.iloc[0]["rank"]
        score = R.iloc[0]["score"]
        doc_id = R.iloc[0]["docid"]
        # print("rank : ", rank)
        # print("score: ", score)
        # print("docid : ", doc_id)
        return {"rank":rank, "docid":doc_id, "score":round(score,2), "qid":qid, "query":query, "label":label}
    else:
        # Then we have document that were not found in the top-1000 ranked documents despite 
        # the query they belong to had a qrel provided
        
        # print("not found")
        return {"rank":-1, "docid":docid, "score":-1, "qid":qid, "query":query, "label":label}

# %%
import pandas as pd
import gc
from tqdm import tqdm

#Given the test qrels, retrieve all the relevant documents and their score in the model in order to check if they have been retrieved
def check_qrel_queries():
    temp1 = dataset.get_topicsqrels("test-2019")[0]
    queries_df = temp1.sort_values(by=['qid'])

    temp2 = dataset.get_topicsqrels("test-2019")[1]
    qrels_df = temp2.sort_values(by=['qid'])
    
    docs_qrels = pd.DataFrame(columns =['rank','docid','score','qid','label'])

    for index, row in tqdm(qrels_df.iterrows()):
        qid = row['qid']

        #We don't care about non-relevant documents, so they are skipped
        if row['label'] == 0:
          continue

        docNo = row["docno"]        
        query = queries_df[queries_df["qid"] == qid].iloc[0]["query"]
        
        # Returns the top 1000 relevant documents for this query (that has as qrel)
        result = bm25.search(query)
        
        docs_qrels = docs_qrels.append(check_rel_doc_present(docNo, qid, query, result,row['label']), ignore_index=True)
        
        del result
        gc.collect()
        
    return docs_qrels

# %%
temp = check_qrel_queries()
# Out:
# 9260it [18:59,  8.12it/s]

# %%
temp.to_csv("QrelAnalysisTest.csv", index=False)

# %%
DOCS = pd.read_csv("collection.tar.gz", sep='\t', header=None, names=["docid","passage"])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
DOCS
# Out:
#                   docid                                            passage
# 0        collection.tsv  The presence of communication amid scientific ...
# 1                     1  The Manhattan Project and its atomic bomb help...
# 2                     2  Essay on The Manhattan Project - The Manhattan...
# 3                     3  The Manhattan Project was the name for a proje...
# 4                     4  versions of each volume as well as complementa...
# ...                 ...                                                ...
# 8841819       8841819.0  Thousands of people across the United States w...
# 8841820       8841820.0  The recipe that creates blue, for example, inc...
# 8841821       8841821.0  On Independence Days of yore, old-timey crowds...
# 8841822       8841822.0  View full size image. Behind the scenes of the...
# 8841823             NaN                                                NaN
#
# [8841824 rows x 2 columns]

# %%
queries_without_doc_retrieved = temp[temp['score']==(-1.00)]

# %%
# RETRIEVE THESE DOCUMENTS TO SEE WHAT IS WRONG
passages = [(DOCS.iloc[(int(x))]['passage']) for x in queries_without_doc_retrieved['docid']]

# %%
queries_without_doc_retrieved['passages'] = passages
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
queries_without_doc_retrieved
# Out:
#      rank    docid  score     qid label                               query  \
# 22     -1  5688423   -1.0  104861     2  cost of interior concrete flooring
# 23     -1  5688422   -1.0  104861     1  cost of interior concrete flooring
# 31     -1  4819155   -1.0  104861     1  cost of interior concrete flooring
# 37     -1  7302612   -1.0  104861     2  cost of interior concrete flooring
# 40     -1  5248343   -1.0  104861     2  cost of interior concrete flooring
# ...   ...      ...    ...     ...   ...                                 ...
# 3980   -1  4284131   -1.0   87452     1          causes of military suicide
# 3981   -1  4307936   -1.0   87452     1          causes of military suicide
# 3982   -1  4079788   -1.0   87452     2          causes of military suicide
# 3983   -1  4096633   -1.0   87452     1          causes of military suicide
# 3984   -1  4233763   -1.0   87452     2          causes of military suicide
#
#                                                passages
# 22    if you wanted an 800 grit polish which is stil...
# 23    extensive surface preparation such as grinding...
# 31    According to Cost Helper, having a professiona...
# 37    Unlike tiles, carpeting and other flooring mat...
# 40    If you wanted an 800 grit polish, which is sti...
# ...                                                 ...
# 3980  Long-Term Effects of PTSD. If left untreated s...
# 3981  Suicide is detrimental to the readiness of the...
# 3982  Understanding Drug Abuse in the Military. The ...
# 3983  Soldiers and Marines who had more combat stres...
# 3984  People suffering from this disorder often use ...
#
# [1271 rows x 7 columns]

# %%
queries_without_doc_retrieved.to_csv("queries_not_retrieved_docs.csv", index=False)
